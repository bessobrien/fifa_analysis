# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
from config import db_password

# %%
# Import provisional files
matches = "data_source/international_matches.csv"
players = "data_source/players_22.csv"

# %%
# Create data frames
matches_df = pd.read_csv(matches, index_col=0)
players_df = pd.read_csv(players, index_col=0)
# Out:
# /var/folders/c3/lcyg_xmn64xd3kc450rqvrc00000gn/T/ipykernel_14220/1563237505.py:3: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   players_df = pd.read_csv(players, index_col=0)

# %%
# Check matches df
matches_df.head()
# Out:
#            home_team     away_team home_team_continent away_team_continent  \
# date
# 1993-08-08   Bolivia       Uruguay       South America       South America
# 1993-08-08    Brazil        Mexico       South America       North America
# 1993-08-08   Ecuador     Venezuela       South America       South America
# 1993-08-08    Guinea  Sierra Leone              Africa              Africa
# 1993-08-08  Paraguay     Argentina       South America       South America
#
#             home_team_fifa_rank  away_team_fifa_rank  \
# date
# 1993-08-08                   59                   22
# 1993-08-08                    8                   14
# 1993-08-08                   35                   94
# 1993-08-08                   65                   86
# 1993-08-08                   67                    5
#
#             home_team_total_fifa_points  away_team_total_fifa_points  \
# date
# 1993-08-08                            0                            0
# ...

# %%
# Check players df
players_df.head()
# Out:
#                                                   player_url  \
# sofifa_id
# 158023     https://sofifa.com/player/158023/lionel-messi/...
# 188545     https://sofifa.com/player/188545/robert-lewand...
# 20801      https://sofifa.com/player/20801/c-ronaldo-dos-...
# 190871     https://sofifa.com/player/190871/neymar-da-sil...
# 192985     https://sofifa.com/player/192985/kevin-de-bruy...
#
#                   short_name                            long_name  \
# sofifa_id
# 158023              L. Messi       Lionel Andrés Messi Cuccittini
# 188545        R. Lewandowski                   Robert Lewandowski
# 20801      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 190871             Neymar Jr        Neymar da Silva Santos Júnior
# 192985          K. De Bruyne                      Kevin De Bruyne
#
#           player_positions  overall  potential    value_eur  wage_eur  age  \
# sofifa_id
# 158023          RW, ST, CF       93         93   78000000.0  320000.0   34
# ...

# %% [markdown]
# Use SQLAlechamy to Import DataFrames into Postgres

# %%
# Create database connection string
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fifa_analysis"

# %%
# Create the database engine
engine = create_engine(db_string)

# %%
# Import dataframes to database
matches_df.to_sql(name='matches', con=engine)
players_df.to_sql(name='players', con=engine)
# Out:
# 239
